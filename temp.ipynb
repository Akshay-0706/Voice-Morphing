# %%
# %pip install librosa

# %%
import numpy as np
import librosa
import librosa.display
import IPython.display as ipd
import os

# %%
ipd.Audio("croc_input.wav")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
def feature_extraction(file_path):
    # load the audio file
    x, sample_rate = librosa.load(file_path, res_type="kaiser_fast")

    # extract features from audio
    mfcc = np.mean(librosa.feature.mfcc(y=x, sr=sample_rate, n_mfcc=50).T, axis = 0)

    return mfcc

# %%
features = {}
audio_path = "croc_input.wav"
features[audio_path] = feature_extraction(audio_path)
# Out:
# x is [0. 0. 0. ... 0. 0. 0.]

# %%
features[audio_path]
# Out:
# array([-2.4634511e+02,  9.2777405e+01, -2.0189775e+01,  3.3086208e+01,
#         7.1632786e+00,  1.9585603e+00, -4.3608913e+00,  7.1747828e+00,
#        -1.1158049e+01,  1.1461163e+01, -8.1329846e-01,  6.4469066e+00,
#        -4.5287952e+00,  7.0520812e-01, -3.3231599e+00,  2.2881787e+00,
#        -9.2197170e+00,  3.6435046e+00, -5.2535324e+00, -2.4845974e+00,
#        -3.7494845e+00, -1.0208368e+00, -2.4202609e+00,  1.5124100e+00,
#        -4.4132504e+00,  7.1208507e-01, -5.1041207e+00, -8.4979880e-01,
#         2.6690264e+00, -2.4064121e+00,  2.2543688e+00, -1.0862308e+00,
#        -1.6659013e+00, -6.9294196e-01, -1.6650339e+00, -1.4859399e+00,
#         1.7680968e-01, -2.7100041e+00, -3.5294592e-01, -2.2439659e+00,
#        -1.7095931e+00, -1.5249232e+00, -2.7647381e+00, -1.8599019e+00,
#        -3.0972404e+00, -3.5529778e+00, -1.9267808e+00, -3.5139854e+00,
#        -2.2807043e+00, -2.7102540e+00], dtype=float32)
